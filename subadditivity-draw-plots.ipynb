# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import random

import bt_mle_utils as mle
from simulation_utils import *

# %%
import pickle

# %% [markdown]
# ## Barbell graph

# %%
objects = []
with (open('additivity_n50_n_bridge10_bridge_L100_L10_average.pickle', "rb")) as openfile:
    while True:
        try:
            objects.append(pickle.load(openfile))
        except EOFError:
            break
n1, n2, n_bridge, bridge_L, L, beta, overlap_list, l_infty_beta_list,\
std_l_infty_beta_list, bar_l_infty_beta_list, rank_beta_list, topk_beta_list, l_infty_beta_add_list, \
std_l_infty_beta_add_list, bar_l_infty_beta_add_list, rank_beta_add_list, topk_beta_add_list = objects[0]

# %%
n1
# Out:
# 50

# %%
diff_list = (beta[1] - beta[0]) * (overlap_list)

# plt.figure(figsize = (9, 6))
plt.plot(diff_list, l_infty_beta_list)
plt.plot(diff_list, l_infty_beta_add_list)
plt.legend(['joint mle', 'additivity'])

# plt.fill_between(diff_list, bar_l_infty_beta_list[:,0], bar_l_infty_beta_list[:,1], color = 'red', alpha = 0.2)
# plt.fill_between(diff_list, bar_l_infty_beta_add_list[:,0], bar_l_infty_beta_add_list[:,1], color = 'blue', alpha = 0.2)
plt.fill_between(diff_list, l_infty_beta_list - std_l_infty_beta_list, 
                 l_infty_beta_list + std_l_infty_beta_list, alpha = 0.2)
plt.fill_between(diff_list, l_infty_beta_add_list - std_l_infty_beta_add_list, 
                 l_infty_beta_add_list + std_l_infty_beta_add_list, alpha = 0.2)
plt.xlabel('shift')
plt.ylabel('l-infinity error')

plt.savefig('additivity_n' + str(n1) + '_n_bridge' + str(n_bridge) + '_average' + '.pdf',bbox_inches='tight')

# %%
diff_list = (beta[1] - beta[0]) * (overlap_list - n1)

# plt.figure(figsize = (9, 6))
plt.plot(diff_list, l_infty_beta_list)
plt.plot(diff_list, l_infty_beta_add_list)
plt.legend(['joint mle', 'additivity'])

# plt.fill_between(diff_list, bar_l_infty_beta_list[:,0], bar_l_infty_beta_list[:,1], color = 'red', alpha = 0.2)
# plt.fill_between(diff_list, bar_l_infty_beta_add_list[:,0], bar_l_infty_beta_add_list[:,1], color = 'blue', alpha = 0.2)
plt.fill_between(diff_list, l_infty_beta_list - std_l_infty_beta_list, 
                 l_infty_beta_list + std_l_infty_beta_list, alpha = 0.2)
plt.fill_between(diff_list, l_infty_beta_add_list - std_l_infty_beta_add_list, 
                 l_infty_beta_add_list + std_l_infty_beta_add_list, alpha = 0.2)
plt.xlabel('diff')
plt.ylabel('l-infinity error')

plt.savefig('additivity_diff_n' + str(n1) + '_n_bridge' + str(n_bridge) + '_average' + '.pdf',bbox_inches='tight')

# %%
plt.plot(diff_list, rank_beta_list)
plt.plot(diff_list, rank_beta_add_list)

# %%
objects = []
with (open('additivity_n100_n_bridge20_bridge_L100_L10_average.pickle', "rb")) as openfile:
    while True:
        try:
            objects.append(pickle.load(openfile))
        except EOFError:
            break
n1, n2, n_bridge, bridge_L, L, beta, overlap_list, l_infty_beta_list,\
std_l_infty_beta_list, bar_l_infty_beta_list, rank_beta_list, topk_beta_list, l_infty_beta_add_list, \
std_l_infty_beta_add_list, bar_l_infty_beta_add_list, rank_beta_add_list, topk_beta_add_list = objects[0]

# %%
diff_list = (beta[1] - beta[0]) * overlap_list

# plt.figure(figsize = (9, 6))
plt.plot(diff_list, l_infty_beta_list)
plt.plot(diff_list, l_infty_beta_add_list)
plt.legend(['joint mle', 'additivity'])

# plt.fill_between(diff_list, bar_l_infty_beta_list[:,0], bar_l_infty_beta_list[:,1], color = 'red', alpha = 0.2)
# plt.fill_between(diff_list, bar_l_infty_beta_add_list[:,0], bar_l_infty_beta_add_list[:,1], color = 'blue', alpha = 0.2)
plt.fill_between(diff_list, l_infty_beta_list - std_l_infty_beta_list, 
                 l_infty_beta_list + std_l_infty_beta_list, alpha = 0.2)
plt.fill_between(diff_list, l_infty_beta_add_list - std_l_infty_beta_add_list, 
                 l_infty_beta_add_list + std_l_infty_beta_add_list, alpha = 0.2)
plt.xlabel('shift')
plt.ylabel('l-infinity error')

plt.savefig('additivity_n' + str(n1) + '_n_bridge' + str(n_bridge) + '_average' + '.pdf',bbox_inches='tight')

# %%
diff_list = (beta[1] - beta[0]) * (overlap_list - n1)

# plt.figure(figsize = (9, 6))
plt.plot(diff_list, l_infty_beta_list)
plt.plot(diff_list, l_infty_beta_add_list)
plt.legend(['joint mle', 'additivity'])

# plt.fill_between(diff_list, bar_l_infty_beta_list[:,0], bar_l_infty_beta_list[:,1], color = 'red', alpha = 0.2)
# plt.fill_between(diff_list, bar_l_infty_beta_add_list[:,0], bar_l_infty_beta_add_list[:,1], color = 'blue', alpha = 0.2)
plt.fill_between(diff_list, l_infty_beta_list - std_l_infty_beta_list, 
                 l_infty_beta_list + std_l_infty_beta_list, alpha = 0.2)
plt.fill_between(diff_list, l_infty_beta_add_list - std_l_infty_beta_add_list, 
                 l_infty_beta_add_list + std_l_infty_beta_add_list, alpha = 0.2)
plt.xlabel('diff')
plt.ylabel('l-infinity error')

plt.savefig('additivity_diff_n' + str(n1) + '_n_bridge' + str(n_bridge) + '_average' + '.pdf',bbox_inches='tight')

# %%
plt.plot(diff_list, rank_beta_list)
plt.plot(diff_list, rank_beta_add_list)

# %% [markdown]
# ## Island graph

# %%
objects = []
with (open('island_additivity_ni_list_no5_k3_L10.pickle', "rb")) as openfile:
    while True:
        try:
            objects.append(pickle.load(openfile))
        except EOFError:
            break
ni_list, no, k, L, l_infty_beta_list, \
std_l_infty_beta_list, bar_l_infty_beta_list, rank_beta_list, topk_beta_list, l_infty_beta_add_list, \
std_l_infty_beta_add_list, bar_l_infty_beta_add_list, rank_beta_add_list, topk_beta_add_list = objects[0]

# %%
plt.plot(ni_list, l_infty_beta_list)
plt.plot(ni_list, l_infty_beta_add_list)
plt.legend(['joint mle', 'additivity'])

# plt.fill_between(diff_list, bar_l_infty_beta_list[:,0], bar_l_infty_beta_list[:,1], color = 'red', alpha = 0.2)
# plt.fill_between(diff_list, bar_l_infty_beta_add_list[:,0], bar_l_infty_beta_add_list[:,1], color = 'blue', alpha = 0.2)
plt.fill_between(ni_list, l_infty_beta_list - std_l_infty_beta_list, 
                 l_infty_beta_list + std_l_infty_beta_list, alpha = 0.2)
plt.fill_between(ni_list, l_infty_beta_add_list - std_l_infty_beta_add_list, 
                 l_infty_beta_add_list + std_l_infty_beta_add_list, alpha = 0.2)
plt.xlabel('ni')
plt.ylabel('l-infinity error')


plt.savefig('island_additivity_ni_list' + '_no' + str(no) + '_k' + str(k) + '_L' + str(L) + '.pdf',bbox_inches='tight')

# %%
plt.plot(ni_list, rank_beta_list)
plt.plot(ni_list, rank_beta_add_list)

# %%
objects = []
with (open('island_additivity_ni50_no5_k5_L10.pickle', "rb")) as openfile:
    while True:
        try:
            objects.append(pickle.load(openfile))
        except EOFError:
            break
ni, no, k, L, overlap_list, l_infty_beta_list, beta, \
std_l_infty_beta_list, bar_l_infty_beta_list, rank_beta_list, topk_beta_list, l_infty_beta_add_list, \
std_l_infty_beta_add_list, bar_l_infty_beta_add_list, rank_beta_add_list, topk_beta_add_list = objects[0]

# %%
diff_list = (beta[1] - beta[0]) * overlap_list

# plt.figure(figsize = (9, 6))
plt.plot(diff_list, l_infty_beta_list)
plt.plot(diff_list, l_infty_beta_add_list)
plt.legend(['joint mle', 'additivity'])

# plt.fill_between(diff_list, bar_l_infty_beta_list[:,0], bar_l_infty_beta_list[:,1], color = 'red', alpha = 0.2)
# plt.fill_between(diff_list, bar_l_infty_beta_add_list[:,0], bar_l_infty_beta_add_list[:,1], color = 'blue', alpha = 0.2)
plt.fill_between(diff_list, l_infty_beta_list - std_l_infty_beta_list, 
                 l_infty_beta_list + std_l_infty_beta_list, alpha = 0.2)
plt.fill_between(diff_list, l_infty_beta_add_list - std_l_infty_beta_add_list, 
                 l_infty_beta_add_list + std_l_infty_beta_add_list, alpha = 0.2)
plt.xlabel('shift')
plt.ylabel('l-infinity error')

plt.savefig('island_additivity_ni' + str(ni) + '_no' + str(no) + '_k' + str(k) + '_L' + str(L) + '.pdf',bbox_inches='tight')

# %%
(beta[1] - beta[0]) *
# Out:
# 0.43176902174729803

# %%
diff_list = (beta[1] - beta[0]) * (overlap_list - (ni - no))

# plt.figure(figsize = (9, 6))
plt.plot(diff_list, l_infty_beta_list)
plt.plot(diff_list, l_infty_beta_add_list)
plt.legend(['joint mle', 'additivity'])

# plt.fill_between(diff_list, bar_l_infty_beta_list[:,0], bar_l_infty_beta_list[:,1], color = 'red', alpha = 0.2)
# plt.fill_between(diff_list, bar_l_infty_beta_add_list[:,0], bar_l_infty_beta_add_list[:,1], color = 'blue', alpha = 0.2)
plt.fill_between(diff_list, l_infty_beta_list - std_l_infty_beta_list, 
                 l_infty_beta_list + std_l_infty_beta_list, alpha = 0.2)
plt.fill_between(diff_list, l_infty_beta_add_list - std_l_infty_beta_add_list, 
                 l_infty_beta_add_list + std_l_infty_beta_add_list, alpha = 0.2)
plt.xlabel('diff')
plt.ylabel('l-infinity error')

plt.savefig('island_additivity_diff_ni' + str(ni) + '_no' + str(no) + '_k' + str(k) + '_L' + str(L) + '.pdf',bbox_inches='tight')

# %%
plt.plot(diff_list, rank_beta_list)
plt.plot(diff_list, rank_beta_add_list)
